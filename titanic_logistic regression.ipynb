# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('titanic_train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(['PassengerId','Name','Ticket'],axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0           0       3    male  22.0      1      0   7.2500   NaN        S
# 1           1       1  female  38.0      1      0  71.2833   C85        C
# 2           1       3  female  26.0      0      0   7.9250   NaN        S
# 3           1       1  female  35.0      1      0  53.1000  C123        S
# 4           0       3    male  35.0      0      0   8.0500   NaN        S
# ..        ...     ...     ...   ...    ...    ...      ...   ...      ...
# 886         0       2    male  27.0      0      0  13.0000   NaN        S
# 887         1       1  female  19.0      0      0  30.0000   B42        S
# 888         0       3  female   NaN      1      2  23.4500   NaN        S
# 889         1       1    male  26.0      0      0  30.0000  C148        C
# 890         0       3    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 9 columns]

# %%
df.isnull()
# Out:
#      Survived  Pclass    Sex    Age  SibSp  Parch   Fare  Cabin  Embarked
# 0       False   False  False  False  False  False  False   True     False
# 1       False   False  False  False  False  False  False  False     False
# 2       False   False  False  False  False  False  False   True     False
# 3       False   False  False  False  False  False  False  False     False
# 4       False   False  False  False  False  False  False   True     False
# ..        ...     ...    ...    ...    ...    ...    ...    ...       ...
# 886     False   False  False  False  False  False  False   True     False
# 887     False   False  False  False  False  False  False  False     False
# 888     False   False  False   True  False  False  False   True     False
# 889     False   False  False  False  False  False  False  False     False
# 890     False   False  False  False  False  False  False   True     False
#
# [891 rows x 9 columns]

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df['Cabin'].isnull().value_counts()
# Out:
# True     687
# False    204
# Name: Cabin, dtype: int64

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=df['Sex'],y=df['Age'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x=df['SibSp'],y=df['Age'])
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Age'>

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
sns.boxplot(x=df['Parch'],y=df['Age'])
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Age'>

# %%
df['Parch'].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 3      5
# 5      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
df[df['Parch']==0]['Age'].mean()
# Out:
# 32.17850287907869

# %%
df[df['Parch']==1]['Age'].mean()
# Out:
# 24.422

# %%
df[df['Parch']==2]['Age'].mean()
# Out:
# 17.216911764705884

# %%
df[df['Parch']==3]['Age'].mean()
# Out:
# 33.2

# %%
df[df['Parch']==4]['Age'].mean()
# Out:
# 44.5

# %%
df[df['Parch']==6]['Age'].mean()
# Out:
# 43.0

# %%
def impuet_age(cols):
    age=cols[0]
    parch=cols[1]
    if pd.isnull(age):
        if parch==0:
            return 32
        elif parch==1:
            return 24
        elif parch==2:
            return 17
        elif parch==3:
            return 33
        elif parch==4:
            return 44
        else:
            return 43
    else:
        return age

# %%
df['Age']=df[['Age','Parch']].apply(impuet_age,axis=1)

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female  17.0      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df['Age'].isnull().value_counts()
# Out:
# False    891
# Name: Age, dtype: int64

# %%
sex=pd.get_dummies(df['Sex'],drop_first=True)

# %%
sex
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 886     1
# 887     0
# 888     0
# 889     1
# 890     1
#
# [891 rows x 1 columns]

# %%
embarked=pd.get_dummies(df['Embarked'],drop_first=True)

# %%
embarked
# Out:
#      Q  S
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 886  0  1
# 887  0  1
# 888  0  1
# 889  0  0
# 890  1  0
#
# [891 rows x 2 columns]

# %%
df=pd.concat([df,sex,embarked],axis=1)

# %%
df.drop(['Sex','Embarked'],axis=1,inplace=True)

# %%
x=df.drop('Survived',axis=1)

# %%
x
# Out:
#      Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0         3  22.0      1      0   7.2500     1  0  1
# 1         1  38.0      1      0  71.2833     0  0  0
# 2         3  26.0      0      0   7.9250     0  0  1
# 3         1  35.0      1      0  53.1000     0  0  1
# 4         3  35.0      0      0   8.0500     1  0  1
# ..      ...   ...    ...    ...      ...   ... .. ..
# 886       2  27.0      0      0  13.0000     1  0  1
# 887       1  19.0      0      0  30.0000     0  0  1
# 888       3  17.0      1      2  23.4500     0  0  1
# 889       1  26.0      0      0  30.0000     1  0  0
# 890       3  32.0      0      0   7.7500     1  1  0
#
# [891 rows x 8 columns]

# %%
y=df['Survived']

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=103)

# %%
x_train
# Out:
#      Pclass    Age  SibSp  Parch      Fare  male  Q  S
# 417       2  18.00      0      2   13.0000     0  0  1
# 305       1   0.92      1      2  151.5500     1  0  1
# 127       3  24.00      0      0    7.1417     1  0  1
# 130       3  33.00      0      0    7.8958     1  0  0
# 465       3  38.00      0      0    7.0500     1  0  1
# ..      ...    ...    ...    ...       ...   ... .. ..
# 825       3  32.00      0      0    6.9500     1  1  0
# 347       3  32.00      1      0   16.1000     0  0  1
# 787       3   8.00      4      1   29.1250     1  1  0
# 73        3  26.00      1      0   14.4542     1  0  0
# 775       3  18.00      0      0    7.7500     1  0  1
#
# [623 rows x 8 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
y_train
# Out:
# 417    1
# 305    1
# 127    1
# 130    0
# 465    0
#       ..
# 825    0
# 347    1
# 787    0
# 73     0
# 775    0
# Name: Survived, Length: 623, dtype: int64

# %%
x_train
# Out:
#      Pclass    Age  SibSp  Parch      Fare  male  Q  S
# 417       2  18.00      0      2   13.0000     0  0  1
# 305       1   0.92      1      2  151.5500     1  0  1
# 127       3  24.00      0      0    7.1417     1  0  1
# 130       3  33.00      0      0    7.8958     1  0  0
# 465       3  38.00      0      0    7.0500     1  0  1
# ..      ...    ...    ...    ...       ...   ... .. ..
# 825       3  32.00      0      0    6.9500     1  1  0
# 347       3  32.00      1      0   16.1000     0  0  1
# 787       3   8.00      4      1   29.1250     1  1  0
# 73        3  26.00      1      0   14.4542     1  0  0
# 775       3  18.00      0      0    7.7500     1  0  1
#
# [623 rows x 8 columns]

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
x_test
# Out:
#      Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 188       3  40.0      1      1  15.5000     1  1  0
# 167       3  45.0      1      4  27.9000     0  0  1
# 212       3  22.0      0      0   7.2500     1  0  1
# 395       3  22.0      0      0   7.7958     1  0  1
# 362       3  45.0      0      1  14.4542     0  0  0
# ..      ...   ...    ...    ...      ...   ... .. ..
# 748       1  19.0      1      0  53.1000     1  0  1
# 333       3  16.0      2      0  18.0000     1  0  1
# 433       3  17.0      0      0   7.1250     1  0  1
# 720       2   6.0      0      1  33.0000     0  0  1
# 511       3  32.0      0      0   8.0500     1  0  1
#
# [268 rows x 8 columns]

# %%
y_pred=model.predict(x_test)

# %%
model.predict_proba(x_test)
# Out:
# array([[0.92484589, 0.07515411],
#        [0.74672334, 0.25327666],
#        [0.86971999, 0.13028001],
#        [0.86956074, 0.13043926],
#        [0.49543564, 0.50456436],
#        [0.53782018, 0.46217982],
#        [0.05943163, 0.94056837],
#        [0.45365822, 0.54634178],
#        [0.91903055, 0.08096945],
#        [0.21228033, 0.78771967],
#        [0.23030397, 0.76969603],
#        [0.15499885, 0.84500115],
#        [0.91056143, 0.08943857],
#        [0.68249345, 0.31750655],
#        [0.17582736, 0.82417264],
#        [0.93347761, 0.06652239],
#        [0.53084233, 0.46915767],
#        [0.82981038, 0.17018962],
#        [0.49584357, 0.50415643],
#        [0.11544636, 0.88455364],
#        [0.92160564, 0.07839436],
#        [0.21132058, 0.78867942],
#        [0.09089455, 0.90910545],
#        [0.3030568 , 0.6969432 ],
#        [0.36198271, 0.63801729],
#        [0.49826396, 0.50173604],
#        [0.42786114, 0.57213886],
#        [0.9117775 , 0.0882225 ],
# ...

# %%
from sklearn import metrics

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.8097014925373134
